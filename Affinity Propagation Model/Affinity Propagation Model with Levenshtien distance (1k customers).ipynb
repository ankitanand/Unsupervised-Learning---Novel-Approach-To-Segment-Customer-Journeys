# %% [markdown]
# ## Table of Contents
#
# [*Approach*](#Approach)
#
# [*Libraries Used*](#Libraries Used)
#
# [*Input Data*](#Input Data)
#
# [*Creating Customer journeys*](#Creating Customer journeys)
#
# [*Output*](#Output)

# %% [markdown]
# <a name="Approach">
# ### Approach : With traditional clustering model after segementing customer journies we end up with clusters without any knowlege of characterstic of individual clusters. The Affinity Propagation Clustering model solves this problem by providing cluster exemplar which is representative of the cluster and thus making it easier to interpret.
# </a>

# %% [markdown]
# <a name="Libraries Used">
# ### Libraries Used : Numpy, Pandas, Time, Matplotlib, Seaborn, Textdistance, re, Sklearn, Distance
# </a>

# %%
# import packages
import numpy as np
import pandas as pd
import time
import matplotlib
import seaborn as sns
import textdistance
import re
import sklearn.cluster
import distance

# %% [markdown]
# <a name="Input Data">
# ### Input Data : Read the input data about customer events
# </a>

# %%
event=pd.read_csv('zpj_sent_event.csv')

# %%
## sort the data by account and time (using event_id as proxy)
event = event.sort_values(by=['newid','event_timestamp','event_id'])

#Total number of unique users in data
event.newid.nunique()
# Out:
# 47327

# %%
event.head()
# Out:
#              newid event_timestamp                       event_name platform  \
# 305631  470.736995       1/18/2018                   past_care.home      web
# 282321  470.736995       1/18/2018  past_care.participants.kimberly      web
# 486561  470.736995       1/18/2018     past_care.participants.brian      web
# 103104  470.736995        2/1/2018            choosing_wisely.shown      web
# 511326  470.736995        2/1/2018               search.filter.page      web
#
#          event_id                      event_session_id event_code
# 305631  441248107  103035b7-ad83-468c-9489-b3cc36a0cbde          .
# 282321  441251503  103035b7-ad83-468c-9489-b3cc36a0cbde          .
# 486561  441251977  103035b7-ad83-468c-9489-b3cc36a0cbde          .
# 103104  451321701  1b96e665-8744-4ad7-a1b2-f1b2c8804857          w
# 511326  451324506  1b96e665-8744-4ad7-a1b2-f1b2c8804857          s

# %% [markdown]
# <a name="Creating Customer journeys">
# ### Creating Customer journeys: As the data for a customer is stored in multiple rows as logs, so we collate the events to create event sequence
# </a>

# %%
df = pd.DataFrame(event.groupby('newid')['event_code'].apply(lambda x: x.sum()))
df = df.reset_index()
df.head()
# Out:
#          newid                                         event_code
# 0   470.736995  ...wssssps.wsSpppwppcfssssss.sws..psSssssssssp...
# 1   497.857109                        ssS..sSppbb..ssspsSssbllSS.
# 2   538.770109                                           .Sbbb.S.
# 3  1311.595552                                                  p
# 4  1372.080296                                 bnnnbbSn..c.bSSSfe

# %%
# We replace repeating events with a single event and remove the uncategorized (dot) events
non_dup = []
for i in range(0,len(df)):
    number = df.iloc[i,1]
    number = number.replace(".","")
    temp_list = []
    for item in number:
        if len(temp_list) == 0:
            temp_list.append(item)

        elif len(temp_list) > 0:
            if  temp_list[-1] != item:
                temp_list.append(item)
    
    non_dup.append(''.join(temp_list))

# %%
# Customers should have minimum 10 events before they can be clustered, also the number of total events is capped to 30. 
df['unq_event'] = non_dup
df1 = df[(df.unq_event.str.len() > 9) & (df.unq_event.str.len() < 31)]
df1.head()
# Out:
#           newid                                         event_code  \
# 0    470.736995  ...wssssps.wsSpppwppcfssssss.sws..psSssssssssp...
# 1    497.857109                        ssS..sSppbb..ssspsSssbllSS.
# 4   1372.080296                                 bnnnbbSn..c.bSSSfe
# 5   1635.667868  b....bcncbbib.nt....b..l.i....nn.bf.p.s.spcc.....
# 17  3237.100318                 f.spp.sp.....ss..s.....b.ib.nb..p.
#
#                    unq_event
# 0     wspswsSpwpcfswspsSspSp
# 1             sSsSpbspsSsblS
# 4                 bnbSncbSfe
# 5   bcncbibntblinbfpspcbtvbt
# 17              fspspsbibnbp

# %%
#create dataframe with just the userid and de-duplicated and cleaned events
df2 = df1.filter(items =['newid','unq_event'])
df2.to_csv("castlight_events2.csv")
seq = df2
seq.head()
# Out:
#           newid                 unq_event
# 0    470.736995    wspswsSpwpcfswspsSspSp
# 1    497.857109            sSsSpbspsSsblS
# 4   1372.080296                bnbSncbSfe
# 5   1635.667868  bcncbibntblinbfpspcbtvbt
# 17  3237.100318              fspspsbibnbp

# %%
#the total number of customers is 10,000 and to test our approach we are using 1,000 customers
seqevent = seq[0:1000]
seqevent.head()
# Out:
#           newid                 unq_event
# 0    470.736995    wspswsSpwpcfswspsSspSp
# 1    497.857109            sSsSpbspsSsblS
# 4   1372.080296                bnbSncbSfe
# 5   1635.667868  bcncbibntblinbfpspcbtvbt
# 17  3237.100318              fspspsbibnbp

# %% [markdown]
# <a name="Output">
# ### Output : Creating final clusters for 1000 customers using Affinity Propagation Clustering model
# </a>

# %%
start_ts = time.time()

# Calculate Levenshtien similarity score between individual customer jouneys to form a similarity matrix
words = np.asarray(np.asarray(seqevent['unq_event'])) #So that indexing with a list will work
lev_similarity = -1*np.array([[distance.levenshtein(w1,w2) for w1 in words] for w2 in words])

# Apply Affinity Propagation Clustering model using damping factor of 0.5 so that clusters get stablized after multiple iterations
affprop = sklearn.cluster.AffinityPropagation(affinity="precomputed", damping=0.5)
affprop.fit(lev_similarity)
for cluster_id in np.unique(affprop.labels_):
    exemplar = words[affprop.cluster_centers_indices_[cluster_id]] # Exemplar: Representative of the clusters elements
    cluster = np.unique(words[np.nonzero(affprop.labels_==cluster_id)])
    cluster_str = ", ".join(cluster) # Cluster elements are separated by comma
    print(" - *%s:* %s" % (exemplar, cluster_str))
    
    
runtime = time.time() - start_ts
print('The pairwise comparison using Levenshtein distance ran for {}'.format(runtime))

## OUTPUT : The pairwise comparison using Levenshtein distance ran for 216.4708869457245
# Out:
#  - *bcncbibntblinbfpspcbtvbt:* bcncbibntblinbfpspcbtvbt
#  - *cbsfinbpfnsbpspbpsbSsSsSsSsSsS:* cbsfinbpfnsbpspbpsbSsSsSsSsSsS
#  - *spfcfcfcspsfSbSpnbfpfpbnfsc:* spfcfcfcspsfSbSpnbfpfpbnfsc
#  - *SlspSbSbspb:* SbScSbSbcplp, SelbspSlblsSbcl, SlfbicSlsnb, SlpSpSbcSp, SlspSbSbspb, SspScSlbsSpbpb, SspspSblSbpbf, bSlsbcfbsp, blSspSbclblSsplb, fwsbnbSbpbs, lspbclSbSblSbS, plsSsbSbslf, psSpSbcnbcpe, sSpspSlSlbSspfsb
#  - *pspspspspspsp:* SbSsSspspspspsS, SsSepSspspspsp, SsbsnbSfpsnbpSsbpspsp, SspspSbpfsfspfspbc, bSpsbfspspspsbS, bSsSpspspspsfsc, blsclbpspspspsp, bpspspblspspsbsp, bwpspspspbspwpwp, bwspspspspswsp, cnbsSpsfwswpwspspsSp, cpcfpfsfpsSfpspef, espspspspspsbfp, fnpwpwpspspwswp, fspsfspsfsfblbsp, pefpfpsewpspspb, psbspsbpswspbpb, psplswspSbsScSlspsp, pspslpspepfpspS, pspspspsSpslSb, pspspspspspsp, pswspspswpwspwspSc, sSpspsSpspspSsb, sSpspspspspsp, spspspspSlSl, wpspspsSspsws
#  - *cspspcpfsfpbpblpbcfpsbcibps:* cspspcpfsfpbpblpbcfpsbcibps
#  - *cspsSepSlSsSscbSwScbcScSps:* cspsSepSlSsSscbSwScbcScSps
#  - *spspepbpspspspspsbntbtnbfbpb:* spspepbpspspspspsbntbtnbfbpb
#  - *ctntbpbcfbfbfbntvfbSpsp:* ctntbpbcfbfbfbntvfbSpsp
#  - *bsplbpspspb:* bSlswlbpslflb, blelewswspl, bsSbpsbsps, bsebspsplbpb, bsfSbSlpbnb, bsplbpspeslblpls, bsplbpspspb, bspsSlbpspspfS, bspsSpSpspe, bspwbwpsepepsS, btfbcbipspncb, cbslblwspspbs, csplblpcpesps, fSfblpspspb, fbfpSsbpsbpb, fbspslblblpswbnb, lbswslclbcfpsps, pfeplSfpspfpc, psSlbspsSpc, spbpbpbspswpbSb
#  - *blblblblblblb:* SelslblsSclblbn, bcblsbSlSbSlblSlsb, bcbwSplblblblbfble, bfblslblplpspblbfnfpb, blblblblblblb, blblblblbsbpb, blbwslbfbnbcpn, blcSlblSlnbsSsSbnbcb, bnbsplbncnbnbvb, bpbpbfsbnblblbn, cblbSlbSbsplfSlcnbfp, fbtblblbcnbtb, fcfibtbpsSblblbl, lblcsplblblb, lpblblblspb
#  - *fpslbspfpbfbfnbpspbcpspspif:* fpslbspfpbfbfnbpspbcpspspif
#  - *SsSpSpSpSpsSp:* ScSpwpsSpsSps, ScSsbpSpSlpSsSpsSspb, SlSsSpsSpSplsScbSlS, SlspspSlSflSfpseSp, SpsSbSpSpSpSspSp, SsSpSpSpSpsSp, SsSsSbSfSspsSp, SsSsSpSpSpSp, SspSpSpSsSpSsSf, SspSpSsSpsSp, beswsSpSpSpSpbsbpsb, bsSpcScScSlspn, bsSpsSpspSpSpspsSp, espSpSpSpsSpse, fpfpSspwSpSpeS, fsSbpSpSsSpbfs, lblsSpSpSpsSp, sSsSpSpSpSpsSp, sbSsSspSspSpsSpsp
#  - *sSpSsSsSspspsSsSsSpsSsp:* SsSpcsSsSepeSspeSspnpsp, bSeSlSbfspspspSswSswsSwsp, bsSspsSsSsSspbeSspspsSsp, pSfSpSsSspsSpsSsSeSpSpSsSpsSsS, sSpSsSsSspspsSsSsSpsSsp, sSpeblbpblspSsSspSpSsp, sSsSfSfspspwspfpsSspsSsSs, sSsSsSsSsSpSsSpsSpsSpsSslc, sbspbsbspspsbsSsSsSsbsp
#  - *fspspsfbfbfn:* SlsSfpsfbfbcncfbc, bfcpspScbibfcbc, bfsfspfsbcnbifbSc, clpspsfsfblcbsfs, esfpspscfbnfpfp, fcSlSpwscbfbfp, fsfnfnpbpfbpfnfbcfbn, fspspsbibnbp, fspspsfbfbfn, lpspscbfsfb, ncfcbsfefcbibfS, npsbfnpspspsbfbfbeb, pwspspwslbfbfbn, sSspfscfcfpbfsfn, sfsSspbsSpblbfbf, spspsfncbfbnb, wspSbnfpfcfbfbfnfb
#  - *SlspSpSpSpSpsSpSsSpSpSpsSbS:* SlspSpSpSpSpsSpSsSpSpSpsSbS, cpspsSpSspSsSpspsSpSspSpSpSsS, fsfbSfsSbSpSpSpsSpSpSpSpSb, sSspSsSsSpSsSpSpSpSpSbspbS
#  - *spsbsnblnbtbnfbntbtntbfbt:* spsbsnblnbtbnfbntbtntbfbt
#  - *npbwsbscfnwsSbnbfbpb:* npbwsbscfnwsSbnbfbpb
#  - *swsbpswseswsblbcbnfefpspspfe:* swsbpswseswsblbcbnfefpspspfe
#  - *bicbfbnbfspsnfnbcibcnpnc:* bicbfbnbfspsnfnbcibcnpnc
#  - *lsfewsbpsbnbfbibfbfspspb:* bsfbtbsbfpfbnbfbnesbfsps, lsfewsbpsbnbfbibfbfspspb
#  - *SsSfSbSepsebfSfSpspbsfbspb:* SsSfSbSepsebfSfSpspbsfbspb
#  - *bsbpfpbfbeswsfsbibSpseseswsp:* bsbpfpbfbeswsfsbibSpseseswsp
#  - *nbcncnbnbnbcbnbncbn:* bncnvbcbibcnbncbncbsn, insnbnbfbncbscbsnbncn, nbcncnbnbnbcbnbncbn, ncnbnbfbfsbcsfbcbcbf
#  - *fpspspspfsfpsfsfnfsbpc:* Sspsplfspfbfsfsfsfsfbib, bsfsfpspsfsfsbfspsfsbfc, fpspspspfsfpsfsfnfsbpc, fslfpscfpfsbcsfnfsfpf
#  - *SsSsSsSsSsSsSsSsSp:* ScScSspwScsSsSspcSbfb, SfspSplSsSspepsSsSspSb, SsSsSsSsSsSsSsSsSp, SspbSsSsSsSspeSpbfbsSlb, bcseSsSbfsfsSsSsSps, bfbspbSsSsSpSpelsSsSlb, bibSpsSsSpSsSsSsSpsSsSpc, bsSpsSsSsSfSsSsSfsfSsSp, bsSsSsSsSpsSsSsSsSsS, bsecbsSsSlsSlSsSbsSs, fSsSfSfSfeSsSwSsSsSw, lsSsSsSsSsSsSsSsSs, lswbswspsSsesSsSpSsSb, pSsSpSsSsSsSsSsS, pSsSsSsplfSsSsSsSsSsSsSs, pbSbScbsSsSsSsSsSsSfpf, pcsSspsSsSsSspSsplSlSlc, pspsefbnfSspsfsSsfSsSe, sSesSpbeSsSpsSsSspSpSspbp, sSsSeSpsSsSsSsSspfSsSs, sSsSsSpbpSspsSsfbSsSb, sSsSsSpsSsSsSspbpsfbsbSfl
#  - *bnftbfswspspwswsewsnbn:* bnftbfswspspwswsewsnbn
#  - *SpsSpSpSsSsS:* ScpscSpSlsS, SlpSpwsSbeS, SpSpSwbsbfpSspS, SpSpSwsSlf, SpsSpSpSsSsS, SpsSpsclspbsp, SpspSfsSsS, SsSpSpSsSsps, blsplpSsSsSp, bpswSpepSwsSwb, bsSpSpsSsSpS, epSpSpspsS, fplSpSpSlfSsp, lbScSseplSpSlSsS, pSpsSspSpSsSpsS, pbSpeSsSspS, psfSpbspefsSsS, sSspsSspSpSspS
#  - *ceSlSpelslswlSsSplSsSls:* ceSlSpelslswlSsSplSsSls
#  - *pspspspsps:* SlspspsplSl, Splspsfsfps, Ssepspspsps, Sspspslpsps, Swpwspspsbls, bfspspspsSps, bpspspspspb, bpspspspwsp, cbpfSsSpsfs, eSpsSspbSe, fbpspwfpcfsepsps, lsbclcpsps, lspwpsesps, npspspspsp, pSsepsfspsps, pbspspswspb, pepesbeses, pfpfpsfbsp, pfpspspspfs, plfsSspspspc, pspSpSpspbS, pspSpsSsplp, pspbsfspsp, pspspcpsfpsb, pspspspSsp, pspspspsps, pwpspswpwpcn, sSpspSpsps, sSpspfpsps, scspspswsps, spesplpspleps, spfpSpsSpl, spsepspsps, spspsfspsps, spspspspspf, spwspswspsws, wpspwspspsSs, wspwpspSwpSn
#  - *cfsfsfcfsfcfcf:* bfeSwsSsfcfncfc, cfsfsfcfpfscnsncnfc, cfsfsfcfsfcfcf, nlsSepsfcfpfcbinfp, swpsfsfcbfbfpcfbf
#  - *sbfbsbsblsbsbsbsftfescf:* sbfbsbsblsbsbsbsftfescf
#  - *scsfspspbsp:* bcfspsfsfp, bwsfswscsp, csbsfsepsnfvspbscfn, cscncsfspscbcbcspb, lcncbfwpsfbpsp, pcfsespbsp, sbSbwsfwspsSfpSsp, scsfspspbsp, sflfbpspwsp, spSfspslfSpSsS, spfsebfsfspwsepe, swsefspspbpbsf, swspslspwsp
#  - *SpSpsSsSpSpsSsSswSwspspfbncb:* SpSpsSsSpSpsSsSswSwspspfbncb
#  - *bfspspsbinbibnfbnfncnbnfbcbcbn:* bfspspsbinbibnfbnfncnbnfbcbcbn
#  - *lbpblbfsfbsbcbfnbtfbfbtf:* lbpblbfsfbsbcbfnbtfbfbtf
#  - *btbtbtbtbtbt:* bfbniftbtntntbtbtntbn, bpswsbtbcfsbcfbtbspt, btbtbtbtbtbt, btbtfctntbcfcftSsbs, nbtntbtbpt, ntbntfcblblfwpte, tbtbtftbtpbnbn, tbtfcfcbtnftbts, tbtntbtfSbl, tcbtcbtftcbtbnbfsctbvt, tctbtlsbtctctcbct, tpbwtntncbntb
#  - *fsSsSpSpSp:* bSlSpSsSpl, bsSsSpScSlsf, bsSsSpbpSp, fSeSpSfSpnbf, flsSspSspfs, fpSpSpSpSp, fpSsSbSpSsp, fpsSpsSpSb, fsSsSpSpSbpbfb, fsSsSpSpSp, lbespsSpSpSbi, nSfsSpSfSsp, pfefSpsSpSp, psSpsSpSlp, sSsSpSpSnb, sSsSpSsSesp, spSswpSpcbeSfep
#  - *bSlSbsSlSlbSlSb:* SlSlbSclspSlSebcSbSb, bSlSbsSlSlbSlSb, cblcSlcbfSfSlSlSl, sSsSspsSlSlSlbSl, spbpsebsclSslbSbSb
#  - *pSsSsSpSsSpSsSpSsSsSpsp:* SpSpSpSsSspSsSpSpSpSsp, SpSsSspSsSsSsSpsSpSspSpsp, SpsSsSpsSspepSpSpsSpSspspsS, SsSsSsSpSpSpSsSpspsSps, SsSsSsSsSsSpSsSpSpsSsSspscpS, SspSsSpSsSlbspSsSpsSbsp, blpsSpsSsSlpSsSpsSsSpsp, bpbpsSsSpSsSpSsSsSlpspsps, lbsSspSsSpSpSpSpSpSbSlbsp, pSpsSspSpspSpSpSpSsSsSsp, pSsSsSpSsSpSsSpSsSsSpsp, psSsSpsSsSsSpSpSpSsSfSpbsb, psSsSsSsSpSsSpsbspsp, sSsSpSpsSpsSsSpsSsSsSpbsb, sSsSpSsSsSsSpsSsbpsp, sSsSpsSpSpspSpSsSpsSsSsS
#  - *SsSpSpSsSsSsSpSp:* SlSspsSpSsSsSpsbSpSsS, SpSsSpSsSsSpsSptbtbtbtS, SsSpSpSsSsSsSpSp, SsSpSsSsbSsSpspSlp, SsSpewswsewSpep, bSpSspSpbsSsSsSpbsw, cSsSpSpsSsSpSpS, pSpSpSpSpsSsSsSsSpS, sSpSspswbsSeSsSpSps, sSspSpSsSsSsSsSp
#  - *bSlbSbfbspbSb:* SbSlbtbtcbsSsSsnc, ScSnfbsfbvbn, bSlbSbfbspbSb, bSlbcScbpsepbnb, bSlspnbspfbnbn, blSsbcbsbSspsfl, blcSblblbfpspsbsSsSsp, lSlbSfSsSpSb, lSlblSsflsSb
#  - *wpsfpspspsfcfsesfpspwswspcbnp:* wpsfpspspsfcfsesfpspwswspcbnp
#  - *pspwswspwSfSpfsfSsSpwpSsSws:* pspwswspwSfSpfsfSsSpwpSsSws
#  - *bsbfbplpbnbfspfbspsvfspbnwncp:* bsbfbplpbnbfspfbspsvfspbnwncp
#  - *spfspfpfpf:* SpepcfsfSpcScfpf, cscfspfpfpfpfsf, fSpfpfpfsc, fSpfsSpfpfSpS, lSfcbfpfpf, lnfpfpcfpncnb, lsbpfsfpfp, lspbfpfbfpfpfp, pSsfnfpfbfSs, pfpfswpfsfpbn, sSpfSfbpfp, sbfbfcfpcpc, sbfbsnlSfbfbpfs, sespSfesfpf, slbpfnfpfpcnbibf, spfspfpfpf, wespswfpfsf
#  - *sSesepSbsb:* SsSslpSlbfsf, sSbpesfpbsp, sSesepSbsb, sSfpesbsblS, sSplSbfbnb, sSslbcpSbs, sbpespsbsbf, sesnbfpfbibi, spSbpswpbSlbsb, spesepeseb
#  - *bpbfbfbfbp:* SbSpfbfpfnc, SbcbfpbfwfsSpSlc, Sbibsfibfbifi, Seblblbfbfs, bfblfblpfibi, bfsbfbebsp, bpbSpfSsSp, bpbfbfbfbp, bpslbcbcnfcbcn, bwbsnbfbnfps, cbfibfifspfbf, cpsfesnbfbfbes, cpvbfpsfbnbfpb, incbwpsbfpfbnfbf, ncbfpnScbfbc, nfebfbtbpbn, pbSbfbfbwswp, sbpbifbibspbpbic, wbSpbcncbfcfnf
#  - *SpspSbicbswpspbfbcbcibnbcbcb:* SpspSbicbswpspbfbcbcibnbcbcb
#  - *nbnSlbnbncn:* SlbncSlSnbn, cbnenbcbnbn, cnblblcnbnfb, elsScbsncncp, fbnlSlwsbcb, nbnSlbnbncn, nbnblbncnc, nsnbfnwsbnc, snbnbnSnbncn, snibnbsnwfsn, spwclbnbcb, spwlnbnbfcn
#  - *bsSsSsSsSb:* SbpsbsSsSsS, SsSsSsSsSb, bSsSbspSsSe, bSsfsSbsSsb, bfSsSpSslbpeSbnb, blSbsSsSsSs, blSspSsSbl, bpSpsSsSsSpbS, bsSpsSsSsSs, bsSsSsSsSb, bsSsSspbSfp, bsbsSsSsbsbsp, bsfSsfSspbf, bswsbScsScbpb, cSbscbSsSlSbps, fbsSsSsSsSebfsc, lSblSfSsSsp, lslcSsSsSl, plbSsSsSsS, sSsSsSsfnfbib, sSsSslScbSb, sSspSsSsSp, slwlbslsSsbspebp
#  - *bSsSsSsSsSpSpSp:* SbSbsSsSsSsSpsbSbl, SsSpSsSswepwpwpw, SswsSswspwbSpspSp, bSsSsSsSsSpSpSp, cesSsSsSsSpSpbswpw, lbSscnspspbSsSbpbspcp, lpSfSswsewpSpSpep, pSsSsSsSspSpsS, pbSsSsSsSpbsSpsSpSpsS, sSsSfSsSsSpsSpS, sSsSsSlspSpSpSp, sSsSsSsSsSpsSfSs
#  - *SsSsSsSpSp:* SfsSsSfsSpncpbcnfnc, SfsSsSsSplSbfp, SsSbSfSfSp, SsSpsSsSpSsp, SsSsSfSpbs, SsSsSpsSpSpl, SsSsSsSpSp, bSpblsSpsSpSp, bSsSsSsSspSp, bsSsSsblSfpsp, cSsSsSsSpSspb, eseSsSspSp, pepSsSspSsSpSp, sSsSsSsSpsp, seSsSsSbsp
#  - *cbfbspsfpbfsnbfpfpb:* bsfbfpbpfpfbfpfbfbpfpb, cbfbspsfpbfsnbfpfpb, lfbpsSpbcfspsbfpfscbf
#  - *sSsSsSsSsSs:* bSsSsSpSfsSs, fpbSsSsSsSsp, fsSpsSsSspSsSs, pspsSsSpSsSs, sSpSsSsbcSsb, sSsSbsSsSsSbSsp, sSsScScSlS, sSsSsSlsbspbsp, sSsSsSpSswsSb, sSsSsSsSsSpcb, sSsSsSsSsSs, sSsSsSsSsblS, sSsSsSspspfs, sSsSsfSsbs, sSsSspbSspsSp, sSsplSsSpsSsS, spSsSsSfesesSf, spsblbsSsSsSsS, spspSsfsSsfs, wSwpsSsesSf
#  - *SbfnbcSblbSbnbnfslbcbsnbs:* SbfnbcSblbSbnbnfslbcbsnbs
#  - *SsSsSbSlsSpsSsSsSsSsSsSsSp:* SlbSbSlSbSlSpsSsSpSpsSsSsSsS, SsSsSbSlsSpsSsSsSsSsSsSsSp, SsSsSsSpSpSsSsSsSsSpSsSsn, blSsSsSlslSsSsSsSblsSsSsSsSs
#  - *sfbfbfsfbpfsfs:* Slswsfbfsfspfsbfspbfp, cwswspbfnbfspspfsfb, fbsflfbnbpscpepfsfefs, pspbfbfsfbfpbfsfpf, sfbfbfsfbpfsfs, slbibfsfbfSnbs
#  - *tnbtfbtbtnfbceSsfpsfsnbfbnbn:* tnbtfbtbtnfbceSsfpsfsnbfbnbn
#  - *pbsbspspsp:* Sbsbfpispspsfpc, Sbwspsepsp, SpbnifsbsSspsp, SpbsSwpwsp, Swswspspsf, bnbnspspsn, bpebsbwswfspsc, bpesblbSpsp, bsbswswsbp, cbwspspspwsp, lSpsbfspsfsp, lbesbspspbspbf, pbsbspspsp, plslblpsbs, psblspsSsSp, pwswpspwfp, spbpfbwsfsSpsSwp
#  - *sfsfsfsfscb:* bpsfesfsfsbew, fsfsfsfcnb, lfsfscsfsfs, sbcfsfswpb, sfcpcfscbcscbc, sfpbfsfspbcb, sfsfcbnwsec, sfsfsbnsbfsf, sfsfsfsfscb, sfspsSsfsnbs, tsfsfbfbsSe
#  - *bfbfbnbnbfcbfb:* bfbfbnbnbfcbfb, bfpfbsbspbnbcb, bnbfbstcfnfbntbnbnb, bsbibvbfbfsfb, cbcbScbnfbnbecbvnb, pswlbnbnfbcbfcbnsfb, sbspcbcbcnbfbfb, tbnbcfbfbtbtbtSfsbSbn
#  - *bSsSpSspSsSspSsSpsSsSpspsSp:* bSsSpSspSsSspSsSpsSsSpspsSp, bpswsweswspSspsSsSspsSps, fSsSpspSepsSfSpfsSsSpfpfSsSsp, pSspSspSsSspSsSpSsSpSpsSsSp
#  - *ncfbnSsSwefpspwSsSfSsSfsfs:* ncfbnSsSwefpspwSsSfSsSfsfs
#  - *sfefspsepbspbpfbfsfspsfsc:* sfefspsepbspbpfbfsfspsfsc
#  - *bcblspspspspspsSspsbfbpbpbeb:* bcblspspspspspsSspsbfbpbpbeb
#  - *lbcpcbspbpbnbespspcnfcnb:* lbcpcbspbpbnbespspcnfcnb
#  - *csfpfsfpsfnfsfnbpfsfbsSsbnb:* csfpfsfpsfnfsfnbpfsfbsSsbnb
#  - *SpfSpspSfSsfSfSsbsSesSsSsSeps:* SpfSpspSfSsfSfSsbsSesSsSsSeps
#  - *SspSspspsp:* SlpSspsSpSpSsp, SsScspspspb, SspSlSpSspesl, SspSpspsSb, SspSspspsp, SspSswsfSfs, SspfcSlpbpsbp, Swspwspspsp, bspwspswsp, flsSbpSsSspsp, lpSspSspspsb, pspeSlspspfsp, wspbSspspew, wsplspswsp, wspwswspsp
#  - *spspsSsSeb:* lbspecsebfe, sbsbpfsSeb, spSpfSlfSb, spsepsSespb, spspsSpsSpw, spspsSsSeb, spspsSsSspbps, swswpsSwscnb
#  - *psSsSsSpspsp:* bsSsSscspspsn, cslspsSsSsSpspsp, lsSlSsplSlspsps, psSsSnbnsfpfb, psSsSpsebsSpspSpb, psSsSsSpspsp, pslSfsesbpfcepc, sSsSpsfpspsp, spspSpsSsSpSspSp
#  - *bSsSsSspSbeSsebnfepsfbfnfn:* bSsSsSspSbeSsebnfepsfbfnfn
#  - *Slspslbfbcnfbfbnsfbfsnbn:* Slspslbfbcnfbfbnsfbfsnbn
#  - *pspbiblblb:* SspbpspbSlblbsp, bSpSpbilbSlbpfb, cSspbnbsbibf, epepbseblbcb, lspelplblsb, nepscbcbnb, pesesbebelbps, pspbiblblb, psplblSblb
#  - *blfcbcfbclpspnbflbspspcpspfcsp:* blfcbcfbclpspnbflbspspcpspfcsp
#  - *spbfwesesfspfeseswespesesese:* spbfwesesfspfeseswespesesese
#  - *bsSbspeswsbtbntbntbtbpbtnbtctn:* bsSbspeswsbtbntbntbtbpbtnbtctn
#  - *fbtfbfbnbspbtntbtncbcnbncbfnit:* fbtfbfbnbspbtntbtncbcnbncbfnit
#  - *spswspsbspspb:* bfbswsesfbswspb, bspfsbsbntnbpnbspspb, bwswsbsbfpswlb, sSswspspSsbpspeb, sbpscbpcbcpbpbn, sbspspebswspS, spsespsclbpspb, spspwspwswsSsb, spswspsbspspb, wpswspsfsbsespelbwpwb, wsbsbwslwspbswbspb
#  - *cSbfpwsfSbSlbnlcfbcfbnbfn:* cSbfpwsfSbSlbnlcfbcfbnbfn
#  - *fspspspspsp:* Sbwcfspfsbfpspfbspfsp, blpcsplspspsp, bwspswbslplslplp, fesefespepsS, fpespsSspsp, fsepspspspbl, fspsfpspsfpspefe, fspspbpspfcps, fspspspspsp, fwpespspsbsf, nfspspfspsfspf, spfpspspsp, spfspspspsp, spwpspwspwp, wspspspspsp
#  - *pspspspcfnbcb:* SspsSspepcfcncn, bwpspbpbspblnfbfb, lspelfsfspbcpbfbcb, pbnbwepspfcbfsctbcbc, pfspfspspfpcbnbncbnfbc, psSpspSptbnctntcbt, pspspspcfnbcb, spspsbcbswspbcnbcbn
#  - *bcwcnbcfbnc:* bcbfswsplbcfslbnbcn, bclcnbpnfnsfs, bcwcnbcfbnc, bpscnbnpbns, cbcbcpepfbcfcscsbpc, lbsfnbcfbl, nlbpbfpcnbcsfsbcncn
# The pairwise comparison using Levenshtein distance ran for 289.3846583366394
